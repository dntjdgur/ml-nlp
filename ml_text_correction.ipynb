# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader, Dataset

from collections import Counter

import os
import re

# %%
nltk.download('punkt');
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /Users/alexwoo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alexwoo/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/alexwoo/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
torch.manual_seed(1);

# %%
word_counter = Counter();

# %%
file_directory = "ml-nlp/dataset"
file_name = "/C4_200M.tsv"

df = pd.read_csv(file_directory + file_name, sep='\t', header=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 file_directory = "ml-nlp/dataset"
#       2 file_name = "/C4_200M.tsv"
# ----> 4 df = pd.read_csv(file_directory + file_name, sep='\t', header=0)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ml-nlp/dataset/C4_200M.tsv'

# %%
df
# Out:
#          Bitcoin is for $7,094 this morning, which CoinDesk says.  \
# 0         The effect of widespread dud targets two face ...
# 1         tax on sales of stores for non residents are s...
# 2         Much many brands and sellers still in the market.
# 3         this is is the latest Maintenance release of S...
# 4         Fairy Or Not, I'm the Godmother: no just look,...
# ...                                                     ...
# 18386516                 Filming for BBC my world kitchen "
# 18386517  These posts categorizeed under Earing and post...
# 18386518  NEWS: Mann Gallery featured in: American Style...
# 18386519       6Let stand a king for 5 mins before serving.
# 18386520  Preheat oven to 356 degrees Fahrenheit. (180 &...
#
#          Bitcoin goes for $7,094 this morning, according to CoinDesk.
# 0         1. The effect of "widespread dud" targets two ...
# 1         Capital Gains tax on the sale of properties fo...
# 2              Many brands and sellers still in the market.
# 3         This is is the latest maintenance release of S...
# 4         Fairy Or Not, I'm the Godmother: Not just a lo...
# ...                                                     ...
# 18386516                Filming for BBC "my world kitchen "
# 18386517  This post categorized under Earing and posted ...
# 18386518  NEWS: Mann Gallery has been featured in: Ameri...
# 18386519         6Leave to stand for 5 mins before serving.
# 18386520  Preheat oven to 356 degrees Fahrenheit (180 de...
#
# [18386521 rows x 2 columns]

# %%
## Add a header data to the new row, salvaging as much data as we can.
new_row = list(df.columns.values)
df.rename(columns={new_row[0]:"incorrect", new_row[1]:"correct"}, inplace=True)
df.loc[df.index.max() + 1] = new_row

# %%
df
# Out:
#                                                   incorrect  \
# 0         The effect of widespread dud targets two face ...
# 1         tax on sales of stores for non residents are s...
# 2         Much many brands and sellers still in the market.
# 3         this is is the latest Maintenance release of S...
# 4         Fairy Or Not, I'm the Godmother: no just look,...
# ...                                                     ...
# 18386517  These posts categorizeed under Earing and post...
# 18386518  NEWS: Mann Gallery featured in: American Style...
# 18386519       6Let stand a king for 5 mins before serving.
# 18386520  Preheat oven to 356 degrees Fahrenheit. (180 &...
# 18386521  Bitcoin is for $7,094 this morning, which Coin...
#
#                                                     correct
# 0         1. The effect of "widespread dud" targets two ...
# 1         Capital Gains tax on the sale of properties fo...
# 2              Many brands and sellers still in the market.
# 3         This is is the latest maintenance release of S...
# 4         Fairy Or Not, I'm the Godmother: Not just a lo...
# ...                                                     ...
# 18386517  This post categorized under Earing and posted ...
# 18386518  NEWS: Mann Gallery has been featured in: Ameri...
# 18386519         6Leave to stand for 5 mins before serving.
# 18386520  Preheat oven to 356 degrees Fahrenheit (180 de...
# 18386521  Bitcoin goes for $7,094 this morning, accordin...
#
# [18386522 rows x 2 columns]

# %%
"""
  Data Preprocessing
  - Drop any duplicates in the dataset
  - Check for any missing values in each column
  - Turn all words in the sentences to lowercase
  - Tokenize the words for each incorrect and correct data
  - Remove any special symbols or characters
  - Normalize the punctuations
"""
column_names = df.columns.tolist();
df.drop_duplicates(inplace=True); # Drop duplicates
df.dropna(inplace=True); # Drop null rows

# %%
def lowercase_words(text):
  text = text.lower(); # Lowercase all words in the sentences
  return text;

def clean_extra_spaces(text):
  text = text.strip(); # Remove any leading and trailing spaces
  text = re.sub(r'\s+', ' ', text); # Replace multiple spaces with a single space
  return text;

def remove_repeated_words(text):
  pattern = r'\b(\w+)( \1\b)+'; # Find repeated words like "is is" or "the the"
  text = re.sub(pattern, r'\1', text);
  return text;

def clean_unwanted_characters(text):
  text = re.sub(r'[^\w\s,.!?\'"]+', '', text); # Remove unnecessary symbols, but keep common punctuations
  return text;

# %%
def data_prerocessing(text):
  text = lowercase_words(text);
  text = clean_extra_spaces(text);
  text = remove_repeated_words(text);
  text = clean_unwanted_characters(text);

  return text;

for column in column_names:
  df[column + "_cleaned"] = df[column].apply(data_prerocessing);

# %%
df
# Out:
#                                                   incorrect  \
# 0         The effect of widespread dud targets two face ...
# 1         tax on sales of stores for non residents are s...
# 2         Much many brands and sellers still in the market.
# 3         this is is the latest Maintenance release of S...
# 4         Fairy Or Not, I'm the Godmother: no just look,...
# ...                                                     ...
# 18386517  These posts categorizeed under Earing and post...
# 18386518  NEWS: Mann Gallery featured in: American Style...
# 18386519       6Let stand a king for 5 mins before serving.
# 18386520  Preheat oven to 356 degrees Fahrenheit. (180 &...
# 18386521  Bitcoin is for $7,094 this morning, which Coin...
#
#                                                     correct  \
# 0         1. The effect of "widespread dud" targets two ...
# 1         Capital Gains tax on the sale of properties fo...
# 2              Many brands and sellers still in the market.
# 3         This is is the latest maintenance release of S...
# 4         Fairy Or Not, I'm the Godmother: Not just a lo...
# ...                                                     ...
# 18386517  This post categorized under Earing and posted ...
# 18386518  NEWS: Mann Gallery has been featured in: Ameri...
# 18386519         6Leave to stand for 5 mins before serving.
# 18386520  Preheat oven to 356 degrees Fahrenheit (180 de...
# 18386521  Bitcoin goes for $7,094 this morning, accordin...
#
#                                           incorrect_cleaned  \
# 0         the effect of widespread dud targets two face ...
# 1         tax on sales of stores for non residents are s...
# 2         much many brands and sellers still in the market.
# 3         this is the latest maintenance release of samb...
# 4         fairy or not, i'm the godmother no just look, ...
# ...                                                     ...
# 18386517  these posts categorizeed under earing and post...
# 18386518  news mann gallery featured in american style m...
# 18386519       6let stand a king for 5 mins before serving.
# 18386520  preheat oven to 356 degrees fahrenheit. 180  d...
# 18386521  bitcoin is for 7,094 this morning, which coind...
#
#                                             correct_cleaned
# 0         1. the effect of "widespread dud" targets two ...
# 1         capital gains tax on the sale of properties fo...
# 2              many brands and sellers still in the market.
# 3         this is the latest maintenance release of samb...
# 4         fairy or not, i'm the godmother not just a loo...
# ...                                                     ...
# 18386517  this post categorized under earing and posted ...
# 18386518  news mann gallery has been featured in america...
# 18386519         6leave to stand for 5 mins before serving.
# 18386520  preheat oven to 356 degrees fahrenheit 180 deg...
# 18386521  bitcoin goes for 7,094 this morning, according...
#
# [18386442 rows x 4 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
